# %%
from bing_image_downloader import downloader

# %%
shoe_brands = ['nike', 'adidas', 'under armour', 'yeezy', 'jordon', 'allbirds']

# %%
for brand in shoe_brands:
    downloader.download(f'{brand} shoes', limit=400, output_dir='./imgs', timeout=60, verbose=True)
# Out:
# [%] Downloading Images to C:\Users\dhruv\Coding\notebooks\shoe_classifier\imgs\nike shoes
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 150 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://sneakernews.com/wp-content/uploads/2019/05/nike-air-max-90-be-true-release-info.jpg
# [!] Issue getting: https://sneakernews.com/wp-content/uploads/2019/05/nike-air-max-90-be-true-release-info.jpg
# [!] Error:: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1091)>
# [%] Downloading Image #1 from https://ae01.alicdn.com/kf/HTB1vikZLMHqK1RjSZFkq6x.WFXa3/Original-Nike-Air-VaporMax-Be-True-Flyknit-Breathable-Men-s-Running-Shoes-Sports-2018-New-Arrival.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.cleatshead.com/wp-content/uploads/2020/04/Nike-Tailwind-79-Be-True-running-shoes-scaled.jpg
# ...
